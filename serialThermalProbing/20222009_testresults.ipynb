# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataFile = pd.read_csv("temps_20220209_1704.csv")

# %%
plt.figure(figsize=(16,12))
x = np.arange(0, len(dataFile['time']))
plt.plot(x, dataFile['ps'])
plt.plot(x, dataFile['pl'])
plt.plot(x, dataFile['ard1'])
plt.plot(x, dataFile['ard2'])
plt.plot(x, dataFile['ard3'])
plt.plot(x, dataFile['ard4'])
plt.plot(x, dataFile['ard5'])

# %%
# Out:
# 0        26.00
# 1        26.00
# 2        26.00
# 3        26.00
# 4        26.00
#          ...
# 16046    27.00
# 16047    27.00
# 16048    26.75
# 16049    27.00
# 16050    27.00
# Name: ard1, Length: 16051, dtype: float64
